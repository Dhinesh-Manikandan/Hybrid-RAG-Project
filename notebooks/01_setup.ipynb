# %% [markdown]
# # 01 Setup & Verification
#
# This notebook verifies environment setup, dependencies, and baseline connection for the Hybrid RAG project.

# %%
import sys

print("Python version:", sys.version)
# Out:
# Python version: 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 15:03:56) [MSC v.1929 64 bit (AMD64)]

# %%
import sys
print(sys.executable)
print(sys.version)
print(sys.maxsize > 2**32)
# Out:
# c:\Users\Dell\anaconda3\python.exe
# 3.12.4 | packaged by Anaconda, Inc. | (main, Jun 18 2024, 15:03:56) [MSC v.1929 64 bit (AMD64)]
# True

# %%
import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import torch
#       3 print("PyTorch version:", torch.__version__)
#       4 print("CUDA available:", torch.cuda.is_available())
#
# File c:\Users\Dell\anaconda3\Lib\site-packages\torch\__init__.py:309
#     305                     raise err
#     307         kernel32.SetErrorMode(prev_error_mode)
# --> 309     _load_dll_libraries()
#     310     del _load_dll_libraries
#     313 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     314     # Libraries can either be in
#     315     # path/nvidia/lib_folder/lib or
#     316     # path/nvidia/cuXX/lib (since CUDA 13.0) or
#     317     # path/lib_folder/lib
#
# File c:\Users\Dell\anaconda3\Lib\site-packages\torch\__init__.py:292, in _load_dll_libraries()
#     288     err = ctypes.WinError(last_error)
# ...

# %%
# %pip install torch torchvision torchaudio sentence-transformers faiss-cpu
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/41.6 kB ? eta -:--:--
#      ---------------------------------------- 41.6/41.6 kB ? eta 0:00:00
# ...
#    ---------------------------------------- 0.0/124.1 MB ? eta -:--:--
#    ---------------------------------------- 0.2/124.1 MB 15.7 MB/s eta 0:00:08
#    ---------------------------------------- 1.1/124.1 MB 11.8 MB/s eta 0:00:11
#     --------------------------------------- 2.3/124.1 MB 16.5 MB/s eta 0:00:08
#    - -------------------------------------- 3.4/124.1 MB 18.1 MB/s eta 0:00:07
#    - -------------------------------------- 4.0/124.1 MB 17.2 MB/s eta 0:00:07
#    - -------------------------------------- 4.2/124.1 MB 15.8 MB/s eta 0:00:08
#    - -------------------------------------- 4.4/124.1 MB 13.5 MB/s eta 0:00:09
#    - -------------------------------------- 4.7/124.1 MB 12.9 MB/s eta 0:00:10
#    - -------------------------------------- 4.8/124.1 MB 11.5 MB/s eta 0:00:11
# ...

# %%
# !pip install -q \
    sentence-transformers \
    faiss-cpu \
    pymupdf \
    nltk \
    scikit-learn \
    pandas \
    numpy \
    tqdm

# %%
from sentence_transformers import SentenceTransformer

embedding_model = SentenceTransformer(
    "all-MiniLM-L6-v2",
    device="cuda"
)

print("Embedding model loaded successfully")
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# Embedding model loaded successfully

# %%
print("Device:", embedding_model.device)
# Out:
# Device: cuda:0

# %%
texts = [
    "Artificial intelligence is a field of computer science.",
    "Retrieval augmented generation uses external knowledge."
]

embeddings = embedding_model.encode(
    texts,
    convert_to_numpy=True
)

print("Embedding shape:", embeddings.shape)
# Out:
# Embedding shape: (2, 384)
